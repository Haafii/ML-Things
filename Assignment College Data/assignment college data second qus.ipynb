# %%
import pandas as pd
import matplotlib.pyplot as plt
from reportlab.lib.pagesizes import letter
from reportlab.pdfgen import canvas
from reportlab.lib.units import inch
import os
import uuid

# Load the CSV file into a DataFrame
data = pd.read_csv('Engineering Student Count Details (College wise - Branch wise).csv')

data['Zone'] = data['Zone'].fillna(method='ffill')

data['Group'] = data['Group'].fillna(method='ffill')

# Remove the records of colleges with categories 'Architecture' and 'Affiliated Autonomous'
data = data[(data['Category Name'] != 'Architecture') & (data['Category Name'] != 'Affiliated Autonomous')]

# Print the resulting DataFrame
#data.to_csv('filtered_data.csv', index=False)

max_total_students = data['Total No of students'].max()
print(f'Highest value in total students column: {max_total_students}')

data.head(10)
# Out:
# Highest value in total students column: 1587
#     College Code                                  College Name  \
# 0           1101  Aalim Muhammed Salegh College Of Engineering
# 1           1101  Aalim Muhammed Salegh College Of Engineering
# 2           1101  Aalim Muhammed Salegh College Of Engineering
# 3           1101  Aalim Muhammed Salegh College Of Engineering
# 4           1101  Aalim Muhammed Salegh College Of Engineering
# 5           1101  Aalim Muhammed Salegh College Of Engineering
# 6           1101  Aalim Muhammed Salegh College Of Engineering
# 9           1103   GRT INSTITUTE OF ENGINEERING AND TECHNOLOGY
# 10          1103   GRT INSTITUTE OF ENGINEERING AND TECHNOLOGY
# 11          1103   GRT INSTITUTE OF ENGINEERING AND TECHNOLOGY
#
#                  Category Name       University    District  \
# 0   Affilated Non - Autonomous  ANNA UNIVERSITY  TIRUVALLUR
# 1   Affilated Non - Autonomous  ANNA UNIVERSITY  TIRUVALLUR
# 2   Affilated Non - Autonomous  ANNA UNIVERSITY  TIRUVALLUR
# 3   Affilated Non - Autonomous  ANNA UNIVERSITY  TIRUVALLUR
# 4   Affilated Non - Autonomous  ANNA UNIVERSITY  TIRUVALLUR
# 5   Affilated Non - Autonomous  ANNA UNIVERSITY  TIRUVALLUR
# 6   Affilated Non - Autonomous  ANNA UNIVERSITY  TIRUVALLUR
# 9   Affilated Non - Autonomous  ANNA UNIVERSITY  TIRUVALLUR
# 10  Affilated Non - Autonomous  ANNA UNIVERSITY  TIRUVALLUR
# 11  Affilated Non - Autonomous  ANNA UNIVERSITY  TIRUVALLUR
#
#                   Zone  Group  \
# 0   Zone I : Chennai-I    1.0
# 1   Zone I : Chennai-I    1.0
# 2   Zone I : Chennai-I    1.0
# 3   Zone I : Chennai-I    1.0
# 4   Zone I : Chennai-I    1.0
# 5   Zone I : Chennai-I    1.0
# 6   Zone I : Chennai-I    1.0
# 9   Zone I : Chennai-I    1.0
# 10  Zone I : Chennai-I    1.0
# 11  Zone I : Chennai-I    1.0
#
#                                              branch  Total No of students  \
# 0     B.E Electronics and Communication Engineering                   160
# 1              B.E Computer Science and Engineering                   394
# 2                             B.E Civil Engineering                    72
# 3        B.E Electrical and Electronics Engineering                    81
# 4                     B.Tech Information Technology                   196
# 5                        B.E Mechanical Engineering                   176
# 6   B.Tech Artificial Intelligence and Data Science                    41
# 9        B.E Electrical and Electronics Engineering                    78
# 10                       B.E Mechanical Engineering                    95
# 11                       B.E Biomedical Engineering                   169
#
#     1st year  2nd year  3rd year  4th year
# 0         37        63        29        31
# 1        110       123        76        85
# 2          7        18        18        29
# 3         10        29        26        16
# 4         57        61        38        40
# 5         18        42        57        59
# 6         41         0         0         0
# 9         25        22        12        19
# 10        16        24        24        31
# 11        42        48        44        35

# %%
for zone in data['Zone'].unique():
    zone_data = data[data['Zone'] == zone]
    plt.figure(figsize=(12, 6))
    plt.hist([zone_data['Total No of students'], zone_data['1st year']], bins=20, alpha=0.5, label=['Total Students', '1st Year'])
    plt.title(f'Histogram for Zone {zone}')
    plt.xlabel('Number of Students')
    plt.ylabel('Frequency')
    plt.legend()
    plt.show()
    plt.close()
